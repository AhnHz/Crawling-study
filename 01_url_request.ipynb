# %%
# !pip install bs4
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=9be06ad7c8deb998accc3ad2b36f6aebc437a4f25af0d43b83617e6e69cb6f7f
#   Stored in directory: /Users/Ahn/Library/Caches/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...

# %%
#<BeautifulSoup library install>
# BeautifulSoup : html 코드를 Python이 이해하는 객체 구조로 변환하는 Parsing을 하는 라이브러리
#1. cmd 명령후 install
# C:\\Users>pip install beautifulsoup4

# %%
# 2. install 후 package 설치 확인 
# C:\\Python36\\Lib\\site-packages\\beautifulsoup4-4.6.3.dist-info
# C:\\Python36\\Lib\\site-packages\\bs4

# %%
# !pip install urllib
# Out:
# ERROR: Could not find a version that satisfies the requirement urllib (from versions: none)
# ERROR: No matching distribution found for urllib

# %%
#1. tag 이름으로 추출 
#2. find()함수로 추출

# %%
#1. tag 이름으로 추출

# %%
import urllib.request # 원격 서버 파일 요청
from bs4 import BeautifulSoup # html 파싱

# 요청할 url
url = 'http://www.naver.com/index.html'

# %%
# 1. 원격 서버 파일 요청
res = urllib.request.urlopen(url) # web 문서 get 
data = res.read() # text 형태로 읽음
print(data)
# Out:
# b'   <!doctype html> <html lang="ko" data-dark="false" class="fzoom"> <head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xe
# ...

# %%
# 2. source 디코딩
src = data.decode("utf-8") # 한글로 디코딩
print('source')
print(src)
# Out:
# source
# ...

# %%
# 3. html 파싱
# html 태그를 인식할 수 있도록 의미있는 단위로 분해하고
# 계층적인 트리 구조를 만드는 과정

html = BeautifulSoup(src, 'html.parser') 
print('html 파싱')
print(html)
# Out:
# html 파싱
#  <!DOCTYPE html>
# ...

# %%
# 4. 태그 내용
a = html.find('a')
print('a tag : ', a)
print('a tag 내용 : ', a.string)
# Out:
# a tag :  <a href="#"><span>바로가기</span></a>
# a tag 내용 :  바로가기

# %%
#2. find()함수로 추출

# %%
#()함수로 추출 
import urllib.request # 원격 서버 파일 요청
from bs4 import BeautifulSoup # html 파싱

# 요청할 url
url = 'http://www.naver.com/index.html'

# 1. 원격 서버 파일 요청
res = urllib.request.urlopen(url) # web 문서 get 
data = res.read() # text 형태로 읽음

# 2. source 디코딩
src = data.decode("utf-8") # 디코딩
print('source')
print(src)
# Out:
# source
# ...

# %%
# 3. html 파싱
html = BeautifulSoup(src, 'html.parser') # html source 파싱
print('html 파싱')
print(html)
# Out:
# html 파싱
#
# <!DOCTYPE doctype html>
# ...

# %%
# 4. 태그 내용
a = html.find('a')
print('a tag : ', a)
print('a tag 내용 : ', a.string)
# Out:
# a tag :  <a href="#"><span>바로가기</span></a>
# a tag 내용 :  바로가기
